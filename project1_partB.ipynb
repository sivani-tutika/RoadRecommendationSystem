# %% [markdown]
# <a href="https://colab.research.google.com/github/sivani-tutika/RoadRecommendationSystem/blob/main/project1_partB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Fundamentals of Artificial Intelligence**

# %% [markdown]
# Course code: CSCE 5210
#
# Section: 002
#
# Pair: 14
#
# **Team members**
#
# ||||
# |--|--|---|
# |**Name:**|Naga Sai **Sivani**, Tutika| **Ketha**, Tirumuru|
# |**Email:**|NagaSaiSivaniTutika@my.unt.edu|KethaTrirumuru@my.unt.edu|
# |**ID:**|11703058|11597873|

# %% [markdown]
# ### Libraries

# %%
import numpy as np
import networkx as nx

# %%
def roadReccomendationSystem(N, p, L, T, k, f):
  pass

# %%
def createConnectedNetwork(N, p, L):
  pass

# %%
def performTrafficAnalysis(G, trips, f, k, B):
  pass

# %%
def findBestRoad(B,G):
  pass

# %%
def spd(X:int, Y:int, G:nx.Graph):
        return nx.astar_path_length(G, X, Y)

# %%
# Out:
# 25
